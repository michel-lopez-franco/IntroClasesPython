# %%
# *Importante informacion es resaltada
# ! Metodo en desuso no usarlo mas adelante
# ? Este metodo deberia ser expuerto  en una API publica?
# TODO: refactorizar este metodo para mejorar su rendimiento
# @param tipo: descripcion del parametro
# Todos Agrega manejo de errores para entradas invalidas

# %%
# Comentario normal
# *Importante*
# ! Nota especial sobre el atributo ruedas
# ? Referencia a documentación externa
